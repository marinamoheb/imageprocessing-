# %% [markdown]
# Name: marina moheb nafee
#
# ID:20180208

# %%
import cv2
import numpy as np
img1 = cv2.imread('333.jpg',0)
# Create zeros array to store the stretched image
minmax_img = np.zeros((img1.shape[0],img1.shape[1]),dtype = 'uint8')

# Loop over the image and apply Min-Max formulae
for i in range(img1.shape[0]):
    for j in range(img1.shape[1]):
        minmax_img[i,j] = 255*(img1[i,j]-np.min(img1))/(np.max(img1)-np.min(img1))

# %%
from matplotlib import pyplot as plt
hist = cv2.calcHist([img1],[0],None,[256],[0,256])
plt.plot(hist)
plt.show()

# %%
from matplotlib import pyplot as plt
hist = cv2.calcHist([minmax_img],[0],None,[256],[0,256])
  
# show the plotting graph of an image
plt.plot(hist)
plt.show()

# %%
cv2_imshow(img1)
cv2_imshow(minmax_img)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FC1350D7150>
# <PIL.Image.Image image mode=L size=256x256 at 0x7FC1350D75D0>
